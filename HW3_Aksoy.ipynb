# %% [markdown]
# **Block 1: Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests

# %%
url='https://en.wikipedia.org/wiki/MonsterVerse' #assign the 
webdata=pd.read_html(url) #assign the data to webdata
full_data= webdata[3]
full_data1=full_data.drop(full_data.index[[5]],axis=0) #get rid of Humans, Humans, Humans
full_data1
# Out:
#               Character  ...                        Films
#               Character  ...            Godzilla vs. Kong
#                Monsters  ...                     Monsters
# 0              Godzilla  ...                          CGI
# 1                  MUTO  ...              Archive footage
# 2             King Kong  ...              Eric PeteyS[57]
# 3         King Ghidorah  ...              Archive footage
# 4                 Rodan  ...              Archive footage
# 6       Ishiro Serizawa  ...                          NaN
# 7       Vivienne Graham  ...                          NaN
# 8        William Stentz  ...                          NaN
# 9            Ford Brody  ...                          NaN
# 10           Elle Brody  ...                          NaN
# 11            Joe Brody  ...                          NaN
# 12         Sandra Brody  ...                          NaN
# 13       Houston Brooks  ...                          NaN
# ...

# %%
webdata[3].head()
# Out:
#        Character  ...             Films
#        Character  ... Godzilla vs. Kong
#         Monsters  ...          Monsters
# 0       Godzilla  ...               CGI
# 1           MUTO  ...   Archive footage
# 2      King Kong  ...   Eric PeteyS[57]
# 3  King Ghidorah  ...   Archive footage
# 4          Rodan  ...   Archive footage
#
# [5 rows x 5 columns]

# %%
print(type(full_data1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
full_data1.index = full_data1['Character']
full_data1.head()
# Out:
#                       Character  ...             Films
#                       Character  ... Godzilla vs. Kong
#                        Monsters  ...          Monsters
# (Godzilla,)            Godzilla  ...               CGI
# (MUTO,)                    MUTO  ...   Archive footage
# (King Kong,)          King Kong  ...   Eric PeteyS[57]
# (King Ghidorah,)  King Ghidorah  ...   Archive footage
# (Rodan,)                  Rodan  ...   Archive footage
#
# [5 rows x 5 columns]

# %%
data=full_data1.set_axis(['Character', 'Godzilla', 'Kong:Skull Island', 'Godzilla:King of the Monsters', 'Godzilla vs. Kong'], axis=1, inplace=False)
data.head(7)
# Out:
#                       Character  ... Godzilla vs. Kong
# (Godzilla,)            Godzilla  ...               CGI
# (MUTO,)                    MUTO  ...   Archive footage
# (King Kong,)          King Kong  ...   Eric PeteyS[57]
# (King Ghidorah,)  King Ghidorah  ...   Archive footage
# (Rodan,)                  Rodan  ...   Archive footage
#
# [5 rows x 5 columns]
#                           Character  ... Godzilla vs. Kong
# (Godzilla,)                Godzilla  ...               CGI
# (MUTO,)                        MUTO  ...   Archive footage
# (King Kong,)              King Kong  ...   Eric PeteyS[57]
# (King Ghidorah,)      King Ghidorah  ...   Archive footage
# (Rodan,)                      Rodan  ...   Archive footage
# (Ishiro Serizawa,)  Ishiro Serizawa  ...               NaN
# (Vivienne Graham,)  Vivienne Graham  ...               NaN
#
# [7 rows x 5 columns]

# %%
data.to_csv('godzilla_data.csv',sep=',')

# %%
data=full_data1.set_axis(['Character', 'Godzilla', 'Kong:Skull Island', 'Godzilla:King of the Monsters', 'Godzilla vs. Kong'], axis=1, inplace=False)
df=data.style.hide_index()
df
# Out:
# <style  type="text/css" >
# </style><table id="T_7ad56b4a_a0c6_11eb_aaeb_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Character</th>        <th class="col_heading level0 col1" >Godzilla</th>        <th class="col_heading level0 col2" >Kong:Skull Island</th>        <th class="col_heading level0 col3" >Godzilla:King of the Monsters</th>        <th class="col_heading level0 col4" >Godzilla vs. Kong</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7ad56b4a_a0c6_11eb_aaeb_0242ac1c0002row0_col0" class="data row0 col0" >Godzilla</td>
#                         <td id="T_7ad56b4a_a0c6_11eb_aaeb_0242ac1c0002row0_col1" class="data row0 col1" >T.J. StormS</td>
#                         <td id="T_7ad56b4a_a0c6_11eb_aaeb_0242ac1c0002row0_col2" class="data row0 col2" >Pictured with archive audio</td>
#                         <td id="T_7ad56b4a_a0c6_11eb_aaeb_0242ac1c0002row0_col3" class="data row0 col3" >T.J. StormS</td>
# ...

# %%
df.to_csv('godzilla_data.csv',sep=',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-222-89d4df4a84c9> in <module>()
# ----> 1 df.to_csv('godzilla_data.csv',sep=',')
#
# AttributeError: 'Styler' object has no attribute 'to_csv'

# %%
type(df)
# Out:
# pandas.io.formats.style.Styler

# %%
type('Characters')
# Out:
# str

# %%
#data2=data.drop(["(Humans,)"],axis=0)
#data2 
#I tried to do a different methods but could not work, even though I was using the string as my index name
